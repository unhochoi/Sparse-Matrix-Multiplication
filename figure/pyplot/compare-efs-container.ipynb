# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# cold 512 EFS
cold_512_efs_total = [58757]
cold_512_efs_run_time = [314]
cold_512_efs_package_import = [41931]
cold_512_efs_run_time_and_package_import = np.array(cold_512_efs_run_time) + np.array(cold_512_efs_package_import)
cold_512_efs_load_model = [15033]
cold_512_efs_run_time_and_package_import_and_load_model = np.array(cold_512_efs_run_time_and_package_import) + np.array(cold_512_efs_load_model)
cold_512_efs_func_exec = [1479]
cold_512_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_512_efs_run_time_and_package_import_and_load_model) + np.array(cold_512_efs_func_exec)

# cold 1024 EFS
cold_1024_efs_total = [35034]
cold_1024_efs_run_time = [123]
cold_1024_efs_package_import = [25554]
cold_1024_efs_run_time_and_package_import = np.array(cold_1024_efs_run_time) + np.array(cold_1024_efs_package_import)
cold_1024_efs_load_model = [8963]
cold_1024_efs_run_time_and_package_import_and_load_model = np.array(cold_1024_efs_run_time_and_package_import) + np.array(cold_1024_efs_load_model)
cold_1024_efs_func_exec = [394]
cold_1024_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_1024_efs_run_time_and_package_import_and_load_model) + np.array(cold_1024_efs_func_exec)

# cold 2048 EFS
cold_2048_efs_total = [32204]
cold_2048_efs_run_time = [74]
cold_2048_efs_package_import = [24455]
cold_2048_efs_run_time_and_package_import = np.array(cold_2048_efs_run_time) + np.array(cold_2048_efs_package_import)
cold_2048_efs_load_model = [7460]
cold_2048_efs_run_time_and_package_import_and_load_model = np.array(cold_2048_efs_run_time_and_package_import) + np.array(cold_2048_efs_load_model)
cold_2048_efs_func_exec = [215]
cold_2048_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_2048_efs_run_time_and_package_import_and_load_model) + np.array(cold_2048_efs_func_exec)

# cold 512 Container
cold_512_container_total = [7773]
cold_512_container_run_time = [715]
cold_512_container_package_import = [5146]
cold_512_container_run_time_and_package_import = np.array(cold_512_container_run_time) + np.array(cold_512_container_package_import)
cold_512_container_load_model = [1053]
cold_512_container_run_time_and_package_import_and_load_model = np.array(cold_512_container_run_time_and_package_import) + np.array(cold_512_container_load_model)
cold_512_container_func_exec = [859]
cold_512_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_512_container_run_time_and_package_import_and_load_model) + np.array(cold_512_container_func_exec)

# cold 1024 Container
cold_1024_container_total = [7482]
cold_1024_container_run_time = [753]
cold_1024_container_package_import = [5172]
cold_1024_container_run_time_and_package_import = np.array(cold_1024_container_run_time) + np.array(cold_1024_container_package_import)
cold_1024_container_load_model = [1115]
cold_1024_container_run_time_and_package_import_and_load_model = np.array(cold_1024_container_run_time_and_package_import) + np.array(cold_1024_container_load_model)
cold_1024_container_func_exec = [442]
cold_1024_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_1024_container_run_time_and_package_import_and_load_model) + np.array(cold_1024_container_func_exec)

# cold 2048 Container
cold_2048_container_total = [7290]
cold_2048_container_run_time = [633]
cold_2048_container_package_import = [5306]
cold_2048_container_run_time_and_package_import = np.array(cold_2048_container_run_time) + np.array(cold_2048_container_package_import)
cold_2048_container_load_model = [1031]
cold_2048_container_run_time_and_package_import_and_load_model = np.array(cold_2048_container_run_time_and_package_import) + np.array(cold_2048_container_load_model)
cold_2048_container_func_exec = [320]
cold_2048_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_2048_container_run_time_and_package_import_and_load_model) + np.array(cold_2048_container_func_exec)

#####################################################################################

fontsize = 30

plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

width = 0.35 # bar 넓이

fig, ax1 = plt.subplots(figsize=(12,9)) # figure 및 subplot 선언

bar = ax1.bar(-0.2, cold_512_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', label='function execution', color='#8C95C6', capsize=20, bottom=cold_512_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(-0.2, cold_512_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', label='model loading' ,color='#9EBCDA', capsize=20, bottom=cold_512_efs_run_time_and_package_import) 
bar = ax1.bar(-0.2, cold_512_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', label='package import',color='lightsteelblue', capsize=20,bottom=cold_512_efs_run_time)    
bar = ax1.bar(-0.2, cold_512_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', label='run-time preparation',color='#E0ECF4', capsize=20)    

bar = ax1.bar(0.2, cold_512_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_512_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(0.2, cold_512_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_512_container_run_time_and_package_import) 
bar = ax1.bar(0.2, cold_512_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_512_container_run_time)    
bar = ax1.bar(0.2, cold_512_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(0.8, cold_1024_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_1024_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(0.8, cold_1024_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.' ,color='#9EBCDA', capsize=20, bottom=cold_1024_efs_run_time_and_package_import) 
bar = ax1.bar(0.8, cold_1024_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_1024_efs_run_time)    
bar = ax1.bar(0.8, cold_1024_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|',color='#E0ECF4', capsize=20)    

bar = ax1.bar(1.2, cold_1024_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_1024_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(1.2, cold_1024_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_1024_container_run_time_and_package_import) 
bar = ax1.bar(1.2, cold_1024_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_1024_container_run_time)    
bar = ax1.bar(1.2, cold_1024_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(1.8, cold_2048_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\',  color='#8C95C6', capsize=20, bottom=cold_2048_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(1.8, cold_2048_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_2048_efs_run_time_and_package_import) 
bar = ax1.bar(1.8, cold_2048_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_2048_efs_run_time)    
bar = ax1.bar(1.8, cold_2048_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(2.2, cold_2048_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_2048_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(2.2, cold_2048_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_2048_container_run_time_and_package_import) 
bar = ax1.bar(2.2, cold_2048_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_2048_container_run_time)    
bar = ax1.bar(2.2, cold_2048_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

#####################################################################################

ax1.set_xticks([-0.2,0.2, 0.8,1.2, 1.8,2.2]) # x축 인덱스
ax1.set_xticklabels(["EFS", "Container\nImage","EFS", "Container\nImage","EFS", "Container\nImage"], fontsize = fontsize * 0.8) # x축 label 이름
ax1.set_xlabel('          512MB              1024MB             2048MB       \n \
                \n \
                Storage - Lambda Memory                 ', labelpad=20)
ax1.tick_params(axis='x',pad=10)

ax1.yaxis.grid(True) # y축만 grid 사용
ax1.set_yticklabels(["0","10","20","30","40","50", "60"])
ax1.set_ylabel('Lambda Invoke Latency (sec)', labelpad=30)

#####################################################################################

ax1.legend(loc="upper right") # 범례 표시
fig.tight_layout() # 이미지 저장시, figure 크기에 맞게 이미지 저장
# fig.savefig('./efs-container-image-cold-experiment.png')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:120: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# cold 512 EFS
warm_512_efs_total = [284]
warm_512_efs_run_time = [0]
warm_512_efs_package_import = [0]
warm_512_efs_run_time_and_package_import = np.array(warm_512_efs_run_time) + np.array(warm_512_efs_package_import)
warm_512_efs_load_model = [0]
warm_512_efs_run_time_and_package_import_and_load_model = np.array(warm_512_efs_run_time_and_package_import) + np.array(warm_512_efs_load_model)
warm_512_efs_func_exec = [284]
warm_512_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_512_efs_run_time_and_package_import_and_load_model) + np.array(warm_512_efs_func_exec)

# cold 1024 EFS
warm_1024_efs_total = [128]
warm_1024_efs_run_time = [0]
warm_1024_efs_package_import = [0]
warm_1024_efs_run_time_and_package_import = np.array(warm_1024_efs_run_time) + np.array(warm_1024_efs_package_import)
warm_1024_efs_load_model = [0]
warm_1024_efs_run_time_and_package_import_and_load_model = np.array(warm_1024_efs_run_time_and_package_import) + np.array(warm_1024_efs_load_model)
warm_1024_efs_func_exec = [128]
warm_1024_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_1024_efs_run_time_and_package_import_and_load_model) + np.array(warm_1024_efs_func_exec)

# cold 2048 EFS
warm_2048_efs_total = [72]
warm_2048_efs_run_time = [0]
warm_2048_efs_package_import = [0]
warm_2048_efs_run_time_and_package_import = np.array(warm_2048_efs_run_time) + np.array(warm_2048_efs_package_import)
warm_2048_efs_load_model = [0]
warm_2048_efs_run_time_and_package_import_and_load_model = np.array(warm_2048_efs_run_time_and_package_import) + np.array(warm_2048_efs_load_model)
warm_2048_efs_func_exec = [72]
warm_2048_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_2048_efs_run_time_and_package_import_and_load_model) + np.array(warm_2048_efs_func_exec)

# cold 512 Container
warm_512_container_total = [286]
warm_512_container_run_time = [0]
warm_512_container_package_import = [0]
warm_512_container_run_time_and_package_import = np.array(warm_512_container_run_time) + np.array(warm_512_container_package_import)
warm_512_container_load_model = [0]
warm_512_container_run_time_and_package_import_and_load_model = np.array(warm_512_container_run_time_and_package_import) + np.array(warm_512_container_load_model)
warm_512_container_func_exec = [286]
warm_512_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_512_container_run_time_and_package_import_and_load_model) + np.array(warm_512_container_func_exec)

# cold 1024 Container
warm_1024_container_total = [123]
warm_1024_container_run_time = [0]
warm_1024_container_package_import = [0]
warm_1024_container_run_time_and_package_import = np.array(warm_1024_container_run_time) + np.array(warm_1024_container_package_import)
warm_1024_container_load_model = [0]
warm_1024_container_run_time_and_package_import_and_load_model = np.array(warm_1024_container_run_time_and_package_import) + np.array(warm_1024_container_load_model)
warm_1024_container_func_exec = [123]
warm_1024_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_1024_container_run_time_and_package_import_and_load_model) + np.array(warm_1024_container_func_exec)

# cold 2048 Container
warm_2048_container_total = [71]
warm_2048_container_run_time = [0]
warm_2048_container_package_import = [0]
warm_2048_container_run_time_and_package_import = np.array(warm_2048_container_run_time) + np.array(warm_2048_container_package_import)
warm_2048_container_load_model = [0]
warm_2048_container_run_time_and_package_import_and_load_model = np.array(warm_2048_container_run_time_and_package_import) + np.array(warm_2048_container_load_model)
warm_2048_container_func_exec = [71]
warm_2048_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_2048_container_run_time_and_package_import_and_load_model) + np.array(warm_2048_container_func_exec)

################################# x축 및 전체 figure 설정 ####################################################

fontsize = 30

plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

width = 0.35 # bar 넓이

fig, ax1 = plt.subplots(figsize=(12,9)) # figure 및 subplot 선언  

bar = ax1.bar(-0.2, warm_512_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', label='function execution', color='#8C95C6', capsize=20, bottom=warm_512_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(-0.2, warm_512_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', label='model loading' ,color='#9EBCDA', capsize=20, bottom=warm_512_efs_run_time_and_package_import) 
bar = ax1.bar(-0.2, warm_512_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', label='package import',color='lightsteelblue', capsize=20,bottom=warm_512_efs_run_time)    
bar = ax1.bar(-0.2, warm_512_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', label='run-time preparation',color='#E0ECF4', capsize=20)    

bar = ax1.bar(0.2, warm_512_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_512_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(0.2, warm_512_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_512_container_run_time_and_package_import) 
bar = ax1.bar(0.2, warm_512_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_512_container_run_time)    
bar = ax1.bar(0.2, warm_512_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(0.8, warm_1024_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_1024_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(0.8, warm_1024_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.' ,color='#9EBCDA', capsize=20, bottom=warm_1024_efs_run_time_and_package_import) 
bar = ax1.bar(0.8, warm_1024_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_1024_efs_run_time)    
bar = ax1.bar(0.8, warm_1024_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|',color='#E0ECF4', capsize=20)    

bar = ax1.bar(1.2, warm_1024_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_1024_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(1.2, warm_1024_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_1024_container_run_time_and_package_import) 
bar = ax1.bar(1.2, warm_1024_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_1024_container_run_time)    
bar = ax1.bar(1.2, warm_1024_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(1.8, warm_2048_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\',  color='#8C95C6', capsize=20, bottom=warm_2048_efs_run_time_and_package_import_and_load_model)   
bar = ax1.bar(1.8, warm_2048_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_2048_efs_run_time_and_package_import) 
bar = ax1.bar(1.8, warm_2048_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_2048_efs_run_time)    
bar = ax1.bar(1.8, warm_2048_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar = ax1.bar(2.2, warm_2048_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_2048_container_run_time_and_package_import_and_load_model)   
bar = ax1.bar(2.2, warm_2048_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_2048_container_run_time_and_package_import) 
bar = ax1.bar(2.2, warm_2048_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_2048_container_run_time)    
bar = ax1.bar(2.2, warm_2048_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

################################# ax1 ####################################################

ax1.set_xticks([-0.2,0.2, 0.8,1.2, 1.8,2.2]) # x축 인덱스
ax1.set_xticklabels(["EFS", "Container\nImage","EFS", "Container\nImage","EFS", "Container\nImage"], fontsize = fontsize * 0.8) # x축 label 이름
ax1.set_xlabel('         512MB             1024MB            2048MB       \n\
                \n\
                Storage - Lambda Memory                ', labelpad=20) # ax1 ylabel 설정
ax1.tick_params(axis='x',pad=10) # x축 label pad

ax1.yaxis.grid(True) # y축만 grid 사용
# ax1.set_ylim([0, 50000])  # 좌측 y축 범위 설정
ax1.set_yticklabels(["0","0.05","0.1","0.15","0.2","0.25", "0.3"]) # x축 label 이름

ax1.set_ylabel('Lambda Invoke Latency (sec)', labelpad=30) # ax1 ylabel 설정

###################################3###################################3###################################3###################################3

ax1.legend(loc="upper right") # 범례 표시



# 이미지 저장시, figure 크기에 맞게 이미지 저장
fig.tight_layout()
fig.savefig('./efs-container-image-warm-experiment.png')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:120: UserWarning: FixedFormatter should only be used together with FixedLocator
