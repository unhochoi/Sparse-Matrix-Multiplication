# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd

# cold_warm = ["Cold", "Warm"]

# # efs (cold, warm)

# efs_total = [47198, 279]

# efs_run_time = [0, 0]
# efs_package_import = [32581, 0]

# efs_run_time_and_package_import = np.array(efs_run_time) + np.array(efs_package_import)

# efs_load_model = [12880, 0]

# efs_run_time_and_package_import_and_load_model = np.array(efs_run_time_and_package_import) + np.array(efs_load_model)

# efs_func_exec = [1417, 279]

# efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(efs_run_time_and_package_import_and_load_model) + np.array(efs_func_exec)


# # container (cold, warm)
# container_total = [7482, 125]

# container_run_time = [1195, 0]
# container_package_import = [5172, 0]

# container_run_time_and_package_import = np.array(container_run_time) + np.array(container_package_import)

# container_load_model = [1115, 0]

# container_run_time_and_package_import_and_load_model = np.array(container_run_time_and_package_import) + np.array(container_load_model)

# container_func_exec = [442, 124]

# container_run_time_and_package_import_and_load_model_and_func_exec = np.array(container_run_time_and_package_import_and_load_model) + np.array(container_func_exec)

# ################################# x축 및 전체 figure 설정 ####################################################

# fontsize = 30

# plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
# plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
# plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
# plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
# plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

# x = np.arange(len(cold_warm)) # x축 인덱스
# width = 0.4 # bar 넓이

# fig, ax1 = plt.subplots(figsize=(12,8)) # figure 및 subplot 선언

# # 각 bar 의 중심 지정
# bar2 = ax1.bar(x - 0.25, efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#959595', capsize=20, bottom=efs_run_time_and_package_import_and_load_model)   
# bar3 = ax1.bar(x - 0.25, efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#BDBDBD', capsize=20, bottom=efs_run_time_and_package_import) 
# bar4 = ax1.bar(x - 0.25, efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='#D9D9D9', capsize=20,bottom=efs_run_time)    
# bar5 = ax1.bar(x - 0.25, efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

# bar7 = ax1.bar(x + 0.25, container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=container_run_time_and_package_import_and_load_model)   
# bar8 = ax1.bar(x + 0.25, container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=container_run_time_and_package_import) 
# bar9 = ax1.bar(x + 0.25, container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=container_run_time)    
# bar10 = ax1.bar(x + 0.25, container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

# bar11 = ax1.bar(x, 0, color = "#1F77B4", hatch='\\', label='Handler')   
# bar12 = ax1.bar(x, 0,  color = "#1F77B4",hatch='.', label='Load Model')   
# bar13 = ax1.bar(x, 0, color = "#1F77B4",hatch='/', label='Package Import')   
# bar14 = ax1.bar(x, 0, color = "#1F77B4",hatch='|', label='Run Time')   


# ################################# ax1 ####################################################

# ax1.set_xticks(x) # x축 인덱스
# ax1.set_xticklabels(cold_warm) # x축 label 이름
# #ax1.set_xlabel(' Cold                             Warm', labelpad=20) # ax1 ylabel 설정
# ax1.tick_params(axis='x',pad=10) # x축 label pad

# ax1.yaxis.grid(True) # y축만 grid 사용
# ax1.set_ylim([0, 50000])  # 좌측 y축 범위 설정
# # ax1.set_yticklabels(["0","5","10","15"]) # x축 label 이름

# ax1.set_ylabel('Lambda Invoke Latency (ms)', labelpad=30) # ax1 ylabel 설정

# ###################################3###################################3###################################3###################################3

# for i in range(len(cold_warm)):
#     ax1.text(x[i] - 0.31, efs_run_time_and_package_import_and_load_model_and_func_exec[i] + 1000, "EFS", fontsize=fontsize*0.75, fontweight='bold') 
#     ax1.text(x[i] + 0.075, container_run_time_and_package_import_and_load_model_and_func_exec[i]+ 1000, "Container", fontsize=fontsize*0.75, fontweight='bold') 

# ax1.legend(loc="upper right") # 범례 표시

# # 이미지 저장시, figure 크기에 맞게 이미지 저장
# fig.tight_layout()
# # fig.savefig('./efs-container-compare.png')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# warm (efs)
warm_efs_total = [279]

warm_efs_run_time = [0]
warm_efs_package_import = [0]

warm_efs_run_time_and_package_import = np.array(warm_efs_run_time) + np.array(warm_efs_package_import)

warm_efs_load_model = [0]

warm_efs_run_time_and_package_import_and_load_model = np.array(warm_efs_run_time_and_package_import) + np.array(warm_efs_load_model)

warm_efs_func_exec = [279]

warm_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_efs_run_time_and_package_import_and_load_model) + np.array(warm_efs_func_exec)

# warm (container)
warm_container_total = [125]

warm_container_run_time = [0]
warm_container_package_import = [0]

warm_container_run_time_and_package_import = np.array(warm_container_run_time) + np.array(warm_container_package_import)

warm_container_load_model = [0]

warm_container_run_time_and_package_import_and_load_model = np.array(warm_container_run_time_and_package_import) + np.array(warm_container_load_model)

warm_container_func_exec = [125]

warm_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_container_run_time_and_package_import_and_load_model) + np.array(warm_container_func_exec)

# cold (efs)
cold_efs_total = [47198]

cold_efs_run_time = [0]
cold_efs_package_import = [32581]

cold_efs_run_time_and_package_import = np.array(cold_efs_run_time) + np.array(cold_efs_package_import)

cold_efs_load_model = [12880]

cold_efs_run_time_and_package_import_and_load_model = np.array(cold_efs_run_time_and_package_import) + np.array(cold_efs_load_model)

cold_efs_func_exec = [1417]

cold_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_efs_run_time_and_package_import_and_load_model) + np.array(cold_efs_func_exec)

# cold (container)
cold_container_total = [7482]

cold_container_run_time = [1195]
cold_container_package_import = [5172]

cold_container_run_time_and_package_import = np.array(cold_container_run_time) + np.array(cold_container_package_import)

cold_container_load_model = [1115]

cold_container_run_time_and_package_import_and_load_model = np.array(cold_container_run_time_and_package_import) + np.array(cold_container_load_model)

cold_container_func_exec = [442]

cold_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_container_run_time_and_package_import_and_load_model) + np.array(cold_container_func_exec)

################################# x축 및 전체 figure 설정 ####################################################

fontsize = 30

plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

x = np.arange(len(cold_warm)) # x축 인덱스
width = 0.8 # bar 넓이

fig, ax1 = plt.subplots(figsize=(12,8)) # figure 및 subplot 선언

# 각 bar 의 중심 지정
bar1 = ax1.bar(0, cold_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#959595', capsize=20, bottom=cold_efs_run_time_and_package_import_and_load_model)   
bar2 = ax1.bar(0, cold_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#BDBDBD', capsize=20, bottom=cold_efs_run_time_and_package_import) 
bar3 = ax1.bar(0, cold_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='#D9D9D9', capsize=20,bottom=cold_efs_run_time)    
bar4 = ax1.bar(0, cold_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar5 = ax1.bar(1, cold_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_container_run_time_and_package_import_and_load_model)   
bar6 = ax1.bar(1, cold_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_container_run_time_and_package_import) 
bar7 = ax1.bar(1, cold_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_container_run_time)    
bar8 = ax1.bar(1, cold_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar9 = ax1.bar(2, warm_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#959595', capsize=20, bottom=warm_efs_run_time_and_package_import_and_load_model)   
bar10 = ax1.bar(2, warm_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#BDBDBD', capsize=20, bottom=warm_efs_run_time_and_package_import) 
bar11 = ax1.bar(2, warm_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='#D9D9D9', capsize=20,bottom=warm_efs_run_time)    
bar12 = ax1.bar(2, warm_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar13 = ax1.bar(3, warm_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_container_run_time_and_package_import_and_load_model)   
bar14 = ax1.bar(3, warm_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_container_run_time_and_package_import) 
bar15 = ax1.bar(3, warm_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_container_run_time)    
bar16 = ax1.bar(3, warm_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    


bar11 = ax1.bar(0, 0, color = "#1F77B4", hatch='\\', label='Handler')   
bar12 = ax1.bar(0, 0,  color = "#1F77B4",hatch='.', label='Load Model')   
bar13 = ax1.bar(0, 0, color = "#1F77B4",hatch='/', label='Package Import')   
bar14 = ax1.bar(0, 0, color = "#1F77B4",hatch='|', label='Run Time')   

################################# ax1 ####################################################

ax1.set_xticks([0,1,2,3]) # x축 인덱스
ax1.set_xticklabels(["EFS","Container", "EFS", "Container"]) # x축 label 이름
ax1.set_xlabel(' Cold                             Warm', labelpad=20) # ax1 ylabel 설정
ax1.tick_params(axis='x',pad=10) # x축 label pad

ax1.yaxis.grid(True) # y축만 grid 사용
# ax1.set_ylim([0, 50000])  # 좌측 y축 범위 설정

ax1.set_ylabel('Lambda Invoke Latency (ms)', labelpad=30) # ax1 ylabel 설정

#######################################################################3###################################3###################################3

ax1.legend(loc="upper right") # 범례 표시

# 이미지 저장시, figure 크기에 맞게 이미지 저장
fig.tight_layout()
fig.savefig('./efs-container-compare.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# warm (efs)
warm_efs_total = [279]

warm_efs_run_time = [0]
warm_efs_package_import = [0]

warm_efs_run_time_and_package_import = np.array(warm_efs_run_time) + np.array(warm_efs_package_import)

warm_efs_load_model = [0]

warm_efs_run_time_and_package_import_and_load_model = np.array(warm_efs_run_time_and_package_import) + np.array(warm_efs_load_model)

warm_efs_func_exec = [279]

warm_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_efs_run_time_and_package_import_and_load_model) + np.array(warm_efs_func_exec)

# warm (container)
warm_container_total = [125]

warm_container_run_time = [0]
warm_container_package_import = [0]

warm_container_run_time_and_package_import = np.array(warm_container_run_time) + np.array(warm_container_package_import)

warm_container_load_model = [0]

warm_container_run_time_and_package_import_and_load_model = np.array(warm_container_run_time_and_package_import) + np.array(warm_container_load_model)

warm_container_func_exec = [125]

warm_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_container_run_time_and_package_import_and_load_model) + np.array(warm_container_func_exec)

# cold (efs)
cold_efs_total = [47198]

cold_efs_run_time = [0]
cold_efs_package_import = [32581]

cold_efs_run_time_and_package_import = np.array(cold_efs_run_time) + np.array(cold_efs_package_import)

cold_efs_load_model = [12880]

cold_efs_run_time_and_package_import_and_load_model = np.array(cold_efs_run_time_and_package_import) + np.array(cold_efs_load_model)

cold_efs_func_exec = [1417]

cold_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_efs_run_time_and_package_import_and_load_model) + np.array(cold_efs_func_exec)

# cold (container)
cold_container_total = [7482]

cold_container_run_time = [1195]
cold_container_package_import = [5172]

cold_container_run_time_and_package_import = np.array(cold_container_run_time) + np.array(cold_container_package_import)

cold_container_load_model = [1115]

cold_container_run_time_and_package_import_and_load_model = np.array(cold_container_run_time_and_package_import) + np.array(cold_container_load_model)

cold_container_func_exec = [442]

cold_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_container_run_time_and_package_import_and_load_model) + np.array(cold_container_func_exec)

################################# x축 및 전체 figure 설정 ####################################################

fontsize = 30

plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

width = 0.2 # bar 넓이

fig, ax1 = plt.subplots(figsize=(12,8)) # figure 및 subplot 선언

# 각 bar 의 중심 지정
bar2 = ax1.bar(-0.2, cold_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#959595', capsize=20, bottom=cold_efs_run_time_and_package_import_and_load_model)   
bar3 = ax1.bar(-0.2, cold_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#BDBDBD', capsize=20, bottom=cold_efs_run_time_and_package_import) 
bar4 = ax1.bar(-0.2, cold_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='#D9D9D9', capsize=20,bottom=cold_efs_run_time)    
bar5 = ax1.bar(-0.2, cold_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar7 = ax1.bar(0.2, cold_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=cold_container_run_time_and_package_import_and_load_model)   
bar8 = ax1.bar(0.2, cold_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=cold_container_run_time_and_package_import) 
bar9 = ax1.bar(0.2, cold_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=cold_container_run_time)    
bar10 = ax1.bar(0.2, cold_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar11 = ax1.bar(0, 0, color = "#1F77B4", hatch='\\', label='Handler')   
bar12 = ax1.bar(0, 0,  color = "#1F77B4",hatch='.', label='Load Model')   
bar13 = ax1.bar(0, 0, color = "#1F77B4",hatch='/', label='Package Import')   
bar14 = ax1.bar(0, 0, color = "#1F77B4",hatch='|', label='Run Time')   

################################# ax1 ####################################################

ax1.set_xticks([-0.2,0.2]) # x축 인덱스
ax1.set_xticklabels(["EFS", "Container"]) # x축 label 이름
ax1.set_xlabel('Cold', labelpad=20) # ax1 ylabel 설정
ax1.tick_params(axis='x',pad=10) # x축 label pad

ax1.yaxis.grid(True) # y축만 grid 사용
# ax1.set_ylim([0, 50000])  # 좌측 y축 범위 설정
# ax1.set_yticklabels(["0","5","10","15"]) # x축 label 이름

ax1.set_ylabel('Lambda Invoke Latency (ms)', labelpad=30) # ax1 ylabel 설정

###################################3###################################3###################################3###################################3

ax1.legend(loc="upper right") # 범례 표시

# 이미지 저장시, figure 크기에 맞게 이미지 저장
fig.tight_layout()
fig.savefig('./efs-container-compare-cold.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# warm (efs)
warm_efs_total = [279]

warm_efs_run_time = [0]
warm_efs_package_import = [0]

warm_efs_run_time_and_package_import = np.array(warm_efs_run_time) + np.array(warm_efs_package_import)

warm_efs_load_model = [0]

warm_efs_run_time_and_package_import_and_load_model = np.array(warm_efs_run_time_and_package_import) + np.array(warm_efs_load_model)

warm_efs_func_exec = [279]

warm_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_efs_run_time_and_package_import_and_load_model) + np.array(warm_efs_func_exec)

# warm (container)
warm_container_total = [125]

warm_container_run_time = [0]
warm_container_package_import = [0]

warm_container_run_time_and_package_import = np.array(warm_container_run_time) + np.array(warm_container_package_import)

warm_container_load_model = [0]

warm_container_run_time_and_package_import_and_load_model = np.array(warm_container_run_time_and_package_import) + np.array(warm_container_load_model)

warm_container_func_exec = [125]

warm_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(warm_container_run_time_and_package_import_and_load_model) + np.array(warm_container_func_exec)

# cold (efs)
cold_efs_total = [47198]

cold_efs_run_time = [0]
cold_efs_package_import = [32581]

cold_efs_run_time_and_package_import = np.array(cold_efs_run_time) + np.array(cold_efs_package_import)

cold_efs_load_model = [12880]

cold_efs_run_time_and_package_import_and_load_model = np.array(cold_efs_run_time_and_package_import) + np.array(cold_efs_load_model)

cold_efs_func_exec = [1417]

cold_efs_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_efs_run_time_and_package_import_and_load_model) + np.array(cold_efs_func_exec)

# cold (container)
cold_container_total = [7482]

cold_container_run_time = [1195]
cold_container_package_import = [5172]

cold_container_run_time_and_package_import = np.array(cold_container_run_time) + np.array(cold_container_package_import)

cold_container_load_model = [1115]

cold_container_run_time_and_package_import_and_load_model = np.array(cold_container_run_time_and_package_import) + np.array(cold_container_load_model)

cold_container_func_exec = [442]

cold_container_run_time_and_package_import_and_load_model_and_func_exec = np.array(cold_container_run_time_and_package_import_and_load_model) + np.array(cold_container_func_exec)

################################# x축 및 전체 figure 설정 ####################################################

fontsize = 30

plt.rc('axes', labelsize=fontsize)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=fontsize)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=fontsize)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=fontsize*0.7)  # 범례 폰트 크기
plt.rcParams['hatch.linewidth'] = 2 # bar pattern 두께

width = 0.2 # bar 넓이

fig, ax1 = plt.subplots(figsize=(12,8)) # figure 및 subplot 선언

# 각 bar 의 중심 지정
bar2 = ax1.bar(-0.2, warm_efs_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#959595', capsize=20, bottom=warm_efs_run_time_and_package_import_and_load_model)   
bar3 = ax1.bar(-0.2, warm_efs_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#BDBDBD', capsize=20, bottom=warm_efs_run_time_and_package_import) 
bar4 = ax1.bar(-0.2, warm_efs_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='#D9D9D9', capsize=20,bottom=warm_efs_run_time)    
bar5 = ax1.bar(-0.2, warm_efs_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar7 = ax1.bar(0.2, warm_container_func_exec, width, linewidth=2, edgecolor='black', hatch='\\', color='#8C95C6', capsize=20, bottom=warm_container_run_time_and_package_import_and_load_model)   
bar8 = ax1.bar(0.2, warm_container_load_model, width, linewidth=2, edgecolor='black', hatch='.', color='#9EBCDA', capsize=20, bottom=warm_container_run_time_and_package_import) 
bar9 = ax1.bar(0.2, warm_container_package_import, width, linewidth=2, edgecolor='black', hatch='/', color='lightsteelblue', capsize=20,bottom=warm_container_run_time)    
bar10 = ax1.bar(0.2, warm_container_run_time, width, linewidth=2, edgecolor='black', hatch='|', color='#E0ECF4', capsize=20)    

bar11 = ax1.bar(0, 0, color = "#1F77B4", hatch='\\', label='Handler')   
bar12 = ax1.bar(0, 0,  color = "#1F77B4",hatch='.', label='Load Model')   
bar13 = ax1.bar(0, 0, color = "#1F77B4",hatch='/', label='Package Import')   
bar14 = ax1.bar(0, 0, color = "#1F77B4",hatch='|', label='Run Time')   

################################# ax1 ####################################################

ax1.set_xticks([-0.2,0.2]) # x축 인덱스
ax1.set_xticklabels(["EFS", "Container"]) # x축 label 이름
ax1.set_xlabel('Warm', labelpad=20) # ax1 ylabel 설정
ax1.tick_params(axis='x',pad=10) # x축 label pad

ax1.yaxis.grid(True) # y축만 grid 사용
ax1.set_ylim([0, 400])  # 좌측 y축 범위 설정
# ax1.set_yticklabels(["0","5","10","15"]) # x축 label 이름

ax1.set_ylabel('Lambda Invoke Latency (ms)', labelpad=30) # ax1 ylabel 설정

###################################3###################################3###################################3###################################3

ax1.legend(loc="upper right") # 범례 표시

# 이미지 저장시, figure 크기에 맞게 이미지 저장
fig.tight_layout()
fig.savefig('./efs-container-compare-warm.png')
plt.show()
