# %%
import numpy as np
import pandas as pd

# amazon_right_sparse_smsm = pd.read_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-sparse-smsm.csv")
# amazon_right_sparse_smdm = pd.read_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-sparse-smdm.csv")

# amazon_right_dense_smsm = pd.read_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-dense-smsm.csv")
# amazon_right_dense_smdm = pd.read_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-dense-smdm.csv")

dblp_right_sparse_smsm = pd.read_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-sparse-smsm.csv")
dblp_right_sparse_smdm = pd.read_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-sparse-smdm.csv")

# dblp_right_dense_smsm = pd.read_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-dense-smsm.csv")
# dblp_right_dense_smdm = pd.read_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-dense-smdm.csv")

# %%
# extract_duplicate_amazon_right_sparse = pd.merge(amazon_right_sparse_smsm, amazon_right_sparse_smdm, left_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], right_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], how='inner')  
# extract_duplicate_amazon_right_sparse

# extract_duplicate_amazon_right_dense = pd.merge(amazon_right_dense_smsm, amazon_right_dense_smdm, left_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], right_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], how='inner')
# extract_duplicate_amazon_right_dense

extract_duplicate_dblp_right_sparse = pd.merge(dblp_right_sparse_smsm, dblp_right_sparse_smdm, left_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], right_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], how='inner') 
extract_duplicate_dblp_right_sparse

# extract_duplicate_dblp_right_dense = pd.merge(dblp_right_dense_smsm, dblp_right_dense_smdm, left_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], right_on=['lr','lc','rc','ld','rd','lnnz','rnnz'], how='inner')
# extract_duplicate_dblp_right_dense
# Out:
#         lr     lc     rc        ld        rd    lnnz  rnnz  \
# 0    30000  20000  10000  0.000024  0.000003   14390   643
# 1    30000  20000  10000  0.000042  0.000003   25162   658
# 2    30000  20000  10000  0.000184  0.000003  110665   593
# 3    30000  20000  10000  0.000040  0.000003   24086   658
# 4    30000  20000  10000  0.000024  0.000003   14406   643
# ..     ...    ...    ...       ...       ...     ...   ...
# 171  17080  20000  10000  0.000008  0.000003    2857   658
# 172  17080  20000  10000  0.000008  0.000003    2616   615
# 173  17080  20000  10000  0.000007  0.000003    2374   654
# 174  17080  20000  10000  0.000007  0.000003    2341   595
# 175  17080  20000  10000  0.000008  0.000003    2606   668
#
#      block_multiply_latency_x  block_multiply_latency_y
# 0                           6                      5180
# 1                           6                      6932
# 2                           5                     11097
# ...

# %%
# extract_duplicate_amazon_right_sparse.to_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-sparse-join.csv",index=False) 

#extract_duplicate_amazon_right_dense.to_csv("/Users/bdlab/Desktop/amazon-334863-334863-10000-right-dense-join.csv",index=False) 

extract_duplicate_dblp_right_sparse.to_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-sparse-join.csv",index=False) 

#extract_duplicate_dblp_right_dense.to_csv("/Users/bdlab/Desktop/dblp-317080-317080-10000-right-dense-join.csv",index=False)
