# %%
import pandas as pd
import numpy as np

# 훈련 데이터셋
df = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/nonsquare-train-1035-from-spmm-contain-todense-over-3s-1293.csv')

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_100 = df.sample(n=100)
index_100.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-100-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_200 = df.sample(n=200)
index_200.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-200-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_300 = df.sample(n=300)
index_300.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-300-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_400 = df.sample(n=400)
index_400.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-400-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_500 = df.sample(n=500)
index_500.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-500-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_600 = df.sample(n=600)
index_600.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-600-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_700 = df.sample(n=700)
index_700.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-700-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_800 = df.sample(n=800)
index_800.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-800-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_900 = df.sample(n=900)
index_900.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-900-using-random.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
index_1000 = df.sample(n=1000)
index_1000.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/spmm-latency-dataset/extract-dataset-using-random/dataset-for-compare-d-optimal/train-data-1000-using-random.csv",index=False)
