# %% [markdown]
# ### Random Test 생성

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-1300-after-spmm.csv")
df
# Out:
#           lr     lc     rc        ld      rd     lnnz      rnnz  \
# 0     133615  48032  11168  0.000470  0.1300  3016572  69735088
# 1      48358  54234   5866  0.000185  0.0700   484326  22272010
# 2     112273  19392   7870  0.000025  0.1300    54060  19840660
# 3      33047  17905   8258  0.008605  0.0010  5092216    147869
# 4     112238  64949   4299  0.000823  0.2500  5998169  69813465
# ...      ...    ...    ...       ...     ...      ...       ...
# 1295   15283  68140  28533  0.000005  0.0005     4832    972131
# 1296   64937  13955   3132  0.002962  0.2500  2684082  10928940
# 1297   13636   6566   2394  0.000563  0.0300    50379    471685
# 1298  105305  27101  13298  0.002962  0.1000  8452833  36040588
# 1299   47493   7813   2483  0.001082  0.0300   401443    582094
#
#       sp_smdm_todense  sp_smdm_multiply  sp_smdm_total  bz_smsm
# 0               16043            118198         134241   234635
# 1                5595             17563          23158    18804
# ...

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_test_300 = df.sample(n=300)
random_test_300.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-test-after-spmm/random-test-300.csv",index=False)

# %%
# 원본 데이터에서 Test 데이터를 제외한 뒤, 저장
df_train = df.drop(index=random_test_300.index)
df_train
# Out:
#           lr     lc     rc        ld      rd     lnnz      rnnz  \
# 0     133615  48032  11168  0.000470  0.1300  3016572  69735088
# 1      48358  54234   5866  0.000185  0.0700   484326  22272010
# 3      33047  17905   8258  0.008605  0.0010  5092216    147869
# 5      48202  56017   3874  0.000563  0.1500  1519212  32556988
# 8      68995  27841  15139  0.000134  0.1300   256697  54796778
# ...      ...    ...    ...       ...     ...      ...       ...
# 1293  143092  65008   3069  0.000153  0.1300  1422960  25936502
# 1295   15283  68140  28533  0.000005  0.0005     4832    972131
# 1296   64937  13955   3132  0.002962  0.2500  2684082  10928940
# 1298  105305  27101  13298  0.002962  0.1000  8452833  36040588
# 1299   47493   7813   2483  0.001082  0.0300   401443    582094
#
#       sp_smdm_todense  sp_smdm_multiply  sp_smdm_total  bz_smsm
# 0               16043            118198         134241   234635
# 1                5595             17563          23158    18804
# ...

# %% [markdown]
# ### Random Test 추출 한 뒤, 나머지에서 Random Train 생성

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_train_200 = df_train.sample(n=200)
random_train_200.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-train-after-spmm/random-train-200.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_train_400 = df_train.sample(n=400)
random_train_400.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-train-after-spmm/random-train-400.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_train_600 = df_train.sample(n=600)
random_train_600.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-train-after-spmm/random-train-600.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_train_800 = df_train.sample(n=800)
random_train_800.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-train-after-spmm/random-train-800.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_train_1000 = df_train.sample(n=1000)
random_train_1000.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-comparison-doe-and-random/random/random-after-spmm/random-train-after-spmm/random-train-1000.csv",index=False)
