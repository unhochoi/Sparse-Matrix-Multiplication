# %% [markdown]
# ### Random Train 생성

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/after-extract-random-test.csv")
df
# Out:
#             lr     lc     rc        ld     rd      lnnz      rnnz
# 0        57535  10084  12623  0.000788  0.250    457065  31824635
# 1        27630  22576  29949  0.009521  0.001   5939065    676146
# 2        73970  41669  13680  0.000185  0.030    569214  17101466
# 3        37458  18422   7698  0.000470  0.100    324360  14182240
# 4       130836  95086   1318  0.004916  0.270  61158357  33852991
# ...        ...    ...    ...       ...    ...       ...       ...
# 876985   76525  52298   6579  0.000822  0.200   3289155  68822638
# 876986  119384  22174  13093  0.009521  0.010  25204373   2903432
# 876987   53020   3349   2723  0.000788  0.005    139890     45613
# 876988   40356  78198  27148  0.000822  0.005   2593640  10614701
# 876989   31618  30456  10820  0.000342  0.050    329740  16477438
#
# [876990 rows x 7 columns]

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_100 = df.sample(n=100)
random_100.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-100.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_200 = df.sample(n=200)
random_200.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-200.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_300 = df.sample(n=300)
random_300.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-300.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_400 = df.sample(n=400)
random_400.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-400.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_500 = df.sample(n=500)
random_500.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-500.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_600 = df.sample(n=600)
random_600.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-600.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_700 = df.sample(n=700)
random_700.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-700.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_800 = df.sample(n=800)
random_800.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-800.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_900 = df.sample(n=900)
random_900.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-900.csv",index=False)

# %%
# 특정 개수만큼 랜덤으로 뽑음
random_1000 = df.sample(n=1000)
random_1000.to_csv("/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/dataset/for-performance-comparison-of-doe-and-random/random-train/random-train-1000.csv",index=False)
